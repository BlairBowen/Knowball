# %%
import unsupervised_learning
import pandas as pd

# %%
query = "SELECT * FROM nfl_player"

# %%
df = unsupervised_learning.fetch_data_from_db(query)
# Out:
# Attempt 1 of 3 to connect to the database...
# ❌ Connection attempt 1 failed: (pyodbc.OperationalError) ('08001', '[08001] [Microsoft][ODBC Driver 18 for SQL Server]TCP Provider: Timeout error [258].  (258) (SQLDriverConnect); [08001] [Microsoft][ODBC Driver 18 for SQL Server]Login timeout expired (0); [08001] [Microsoft][ODBC Driver 18 for SQL Server]Invalid connection string attribute (0); [08001] [Microsoft][ODBC Driver 18 for SQL Server]Unable to complete login process due to delay in login response (258)')
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Retrying in 3 seconds...
# Attempt 2 of 3 to connect to the database...
# ❌ Connection attempt 2 failed: (pyodbc.OperationalError) ('08001', '[08001] [Microsoft][ODBC Driver 18 for SQL Server]TCP Provider: Timeout error [258].  (258) (SQLDriverConnect); [08001] [Microsoft][ODBC Driver 18 for SQL Server]Login timeout expired (0); [08001] [Microsoft][ODBC Driver 18 for SQL Server]Invalid connection string attribute (0); [08001] [Microsoft][ODBC Driver 18 for SQL Server]Unable to complete login process due to delay in login response (258)')
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Retrying in 3 seconds...
# Attempt 3 of 3 to connect to the database...
# ✅ Connection successful!

# %%
df
# Out:
#         ID             Player Until    G  GS  Cmp  PaAtt  Cmp%  PaYds  PaTD  \
# 0        1  Israel Abanikanda  2023    6   0    0      0   NaN      0     0
# 1        2     Ameer Abdullah  2024  141  26    0      0   NaN      0     0
# 2        3     Yasir Abdullah  2024   19   3    0      0   NaN      0     0
# 3        4    Micah Abernathy  2024   20   0    0      0   NaN      0     0
# 4        5    Johnathan Abram  2024   55  39    0      0   NaN      0     0
# ...    ...                ...   ...  ...  ..  ...    ...   ...    ...   ...
# 2695  2696         Ty Zentner  2024   10   0    0      0   NaN      0     0
# 2696  2697         Zak Zinter  2024   17   3    0      0   NaN      0     0
# 2697  2698       Isaiah Zuber  2020    4   0    0      0   NaN      0     0
# 2698  2699      Greg Zuerlein  2024  192   0    0      0   NaN      0     0
# 2699  2700      Shane Zylstra  2024   29   3    0      0   NaN      0     0
#
#       ...                 Team  MVP  OPOY  DPOY  OROY  DROY  AP1  SB    IG  \
# 0     ...                  NYJ    0     0     0     0     0    0   0  None
# 1     ...      CAR,DET,LVR,MIN    0     0     0     0     0    0   0  None
# 2     ...                  JAX    0     0     0     0     0    0   0  None
# 3     ...              ATL,GNB    0     0     0     0     0    0   0  None
# 4     ...  GNB,LVR,NOR,OAK,SEA    0     0     0     0     0    0   0  None
# ...   ...                  ...  ...   ...   ...   ...   ...  ...  ..   ...
# 2695  ...          HOU,LAR,TEN    0     0     0     0     0    0   0  None
# 2696  ...                  CLE    0     0     0     0     0    0   0  None
# 2697  ...                  NWE    0     0     0     0     0    0   0  None
# 2698  ...      DAL,LAR,NYJ,STL    0     0     0     0     0    0   0  None
# 2699  ...                  DET    0     0     0     0     0    0   0  None
#
#           Wiki
# 0      48136.0
# 1     118158.0
# 2       9650.0
# 3       8885.0
# 4          NaN
# ...        ...
# 2695       NaN
# 2696   90207.0
# 2697       NaN
# 2698       NaN
# 2699   26568.0
#
# [2700 rows x 60 columns]

# %%
nba_df = pd.read_csv("../nfl.csv")

# %%
nba_df = nba_df.loc[:, ~nba_df.columns.str.contains('Unnamed')]

# %%
nba_df
# Out:
#                        Team               Player  Pageviews
# 0         Arizona Cardinals         Kyler Murray   845475.0
# 1         Arizona Cardinals         Clayton Tune    56850.0
# 2         Arizona Cardinals          Trey Benson   110208.0
# 3         Arizona Cardinals       Michael Carter    50197.0
# 4         Arizona Cardinals         James Conner   198361.0
# ...                     ...                  ...        ...
# 2215  Washington Commanders         Bobby Wagner   384744.0
# 2216  Washington Commanders         Mykal Walker    16624.0
# 2217  Washington Commanders            Tress Way    66983.0
# 2218  Washington Commanders    Olamide Zaccheaus    74418.0
# 2219  Washington Commanders  Chris Rodriguez Jr.    60419.0
#
# [2220 rows x 3 columns]

# %%
df = df.rename(columns={"Player": "Player_df1"})
nba_df = nba_df.rename(columns={"Player": "Player_df2"})

# %%
new_merge_df = unsupervised_learning.fuzzy_merge(df, nba_df, "Player_df1", "Player_df2")

# %%
new_merge_df.columns
# Out:
# Index(['ID', 'Player_df1', 'Until', 'G', 'GS', 'Cmp', 'PaAtt', 'Cmp%', 'PaYds',
#        'PaTD', 'IntO', 'Rate', 'SkO', 'QBWin', 'GWD', 'RuAtt', 'RuYds',
#        'RuY/A', 'RuTD', 'RuY/G', 'Tgt', 'Rec', 'RecYds', 'Y/Rec', 'RecTD',
#        'RecY/G', 'FG', 'FG%', '2PM', 'Sfty', 'Pts', 'FantPts', 'SkD', 'Solo',
#        'Ast', 'TFL', 'QBHit', 'IntD', 'Pick6', 'PaDef', 'Fmb', 'FR', 'Scoop6',
#        'FF', 'PntYds', 'Y/Pnt', 'Blck', 'APYd', 'RetYds', 'Pos', 'Team_x',
#        'MVP', 'OPOY', 'DPOY', 'OROY', 'DROY', 'AP1', 'SB', 'IG', 'Wiki',
#        'Player_df2', 'Match Score', 'Team_y', 'Pageviews'],
#       dtype='object')

# %%
df = new_merge_df

# %%
# # Define function to compute per-game stats safely (avoid division by zero)
# def per_game(stat, games_played):
#     return stat / games_played if games_played > 0 else 0

# # Apply function to relevant columns
# df['PPG'] = df.apply(lambda row: per_game(row['PTS'], row['G']), axis=1)
# df['APG'] = df.apply(lambda row: per_game(row['AST'], row['G']), axis=1)
# df['RPG'] = df.apply(lambda row: per_game(row['TRB'], row['G']), axis=1)
# df['MPG'] = df.apply(lambda row: per_game(row['MP'], row['G']), axis=1)
# df['FGAPG'] = df.apply(lambda row: per_game(row['FG'], row['G']), axis=1)
# df['2PPG'] = df.apply(lambda row: per_game(row['2P'], row['G']), axis=1)
# df['2PAPG'] = df.apply(lambda row: per_game(row['2PA'], row['G']), axis=1)
# df['3PPG'] = df.apply(lambda row: per_game(row['3P'], row['G']), axis=1)
# df['3PAPG'] = df.apply(lambda row: per_game(row['3PA'], row['G']), axis=1)
# df['FTPG'] = df.apply(lambda row: per_game(row['FT'], row['G']), axis=1)
# df['FTAPG'] = df.apply(lambda row: per_game(row['FTA'], row['G']), axis=1)
# df['SPG'] = df.apply(lambda row: per_game(row['STL'], row['G']), axis=1)
# df['BPG'] = df.apply(lambda row: per_game(row['BLK'], row['G']), axis=1)
# df['TPG'] = df.apply(lambda row: per_game(row['TOV'], row['G']), axis=1)
# df['FPG'] = df.apply(lambda row: per_game(row['PF'], row['G']), axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PTS'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 6
#       3     return stat / games_played if games_played > 0 else 0
#       5 # Apply function to relevant columns
# ----> 6 df['PPG'] = df.apply(lambda row: per_game(row['PTS'], row['G']), axis=1)
#       7 df['APG'] = df.apply(lambda row: per_game(row['AST'], row['G']), axis=1)
#       8 df['RPG'] = df.apply(lambda row: per_game(row['TRB'], row['G']), axis=1)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:9568, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9557 from pandas.core.apply import frame_apply
#    9559 op = frame_apply(
#    9560     self,
#    9561     func=func,
#    (...)
#    9566     kwargs=kwargs,
#    9567 )
# -> 9568 return op.apply().__finalize__(self, method="apply")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\apply.py:764, in FrameApply.apply(self)
#     761 elif self.raw:
#     762     return self.apply_raw()
# --> 764 return self.apply_standard()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\apply.py:891, in FrameApply.apply_standard(self)
#     890 def apply_standard(self):
# --> 891     results, res_index = self.apply_series_generator()
#     893     # wrap results
#     894     return self.wrap_results(results, res_index)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\apply.py:907, in FrameApply.apply_series_generator(self)
#     904 with option_context("mode.chained_assignment", None):
#     905     for i, v in enumerate(series_gen):
#     906         # ignore SettingWithCopy here in case the user mutates
# --> 907         results[i] = self.f(v)
#     908         if isinstance(results[i], ABCSeries):
#     909             # If we have a view on v, we need to make a copy because
#     910             #  series_generator will swap out the underlying data
#     911             results[i] = results[i].copy(deep=False)
#
# Cell In[15], line 6, in <lambda>(row)
#       3     return stat / games_played if games_played > 0 else 0
#       5 # Apply function to relevant columns
# ----> 6 df['PPG'] = df.apply(lambda row: per_game(row['PTS'], row['G']), axis=1)
#       7 df['APG'] = df.apply(lambda row: per_game(row['AST'], row['G']), axis=1)
#       8 df['RPG'] = df.apply(lambda row: per_game(row['TRB'], row['G']), axis=1)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'PTS'

# %%
df = (df
                .drop(columns=["Player_df2", "Team_x"])
                .rename(columns={'Player_df1': 'Player', 'Team_y': 'Team'})
    )

# %%
unmatched_players = df[["Player", "G"]].loc[df["G"].isna()]

# %%
display(unmatched_players.style.set_sticky())  # Keeps headers visible while scrolling
# Out:
# <style type="text/css">
# #T_af344 thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_af344 tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 1;
# }
# </style>
# <table id="T_af344">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_af344_level0_col0" class="col_heading level0 col0" >Player</th>
#       <th id="T_af344_level0_col1" class="col_heading level0 col1" >G</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
# !pip install --upgrade pip
# !pip install scikit-learn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
df.columns
# Out:
# Index(['ID', 'Player', 'Until', 'G', 'GS', 'Cmp', 'PaAtt', 'Cmp%', 'PaYds',
#        'PaTD', 'IntO', 'Rate', 'SkO', 'QBWin', 'GWD', 'RuAtt', 'RuYds',
#        'RuY/A', 'RuTD', 'RuY/G', 'Tgt', 'Rec', 'RecYds', 'Y/Rec', 'RecTD',
#        'RecY/G', 'FG', 'FG%', '2PM', 'Sfty', 'Pts', 'FantPts', 'SkD', 'Solo',
#        'Ast', 'TFL', 'QBHit', 'IntD', 'Pick6', 'PaDef', 'Fmb', 'FR', 'Scoop6',
#        'FF', 'PntYds', 'Y/Pnt', 'Blck', 'APYd', 'RetYds', 'Pos', 'MVP', 'OPOY',
#        'DPOY', 'OROY', 'DROY', 'AP1', 'SB', 'IG', 'Wiki', 'Match Score',
#        'Team', 'Pageviews'],
#       dtype='object')

# %%
# df = pd.get_dummies(df, columns=['Team'], drop_first=True)

# %%
df_cols = list(df.columns)
df_cols = list(set(df_cols) - set(['Wiki', 'Match Score', 'Until', 'ID', 'Player', 'Team', "Pos", "IG"]))

# %%
df_cols
# Out:
# ['Y/Pnt',
#  'Cmp%',
#  'RecYds',
#  'PaYds',
#  'Pick6',
#  'OROY',
#  'Rec',
#  'Pageviews',
#  'Sfty',
#  'FF',
#  'Pts',
#  'DROY',
#  'Ast',
#  'FR',
#  'PaDef',
#  'Blck',
#  'RuY/G',
#  'GWD',
#  'FG%',
#  'Scoop6',
#  'RetYds',
#  'DPOY',
#  'Tgt',
#  'RuAtt',
#  'PntYds',
#  'AP1',
#  'TFL',
#  'Y/Rec',
#  'Cmp',
#  'PaTD',
#  'SkD',
#  'MVP',
#  'QBWin',
#  'APYd',
#  'OPOY',
#  'Rate',
#  'GS',
#  'RecY/G',
#  'SB',
#  'IntO',
#  'FantPts',
#  'SkO',
#  'PaAtt',
#  'FG',
#  'IntD',
#  'RecTD',
#  'QBHit',
#  'Fmb',
#  'RuTD',
#  'RuY/A',
#  'Solo',
#  '2PM',
#  'G',
#  'RuYds']

# %%
# df.dropna(inplace=True)
df.fillna(df.median(), inplace=True)
# Out:
# C:\Users\Blair\AppData\Local\Temp\ipykernel_18104\2105182659.py:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.median(), inplace=True)

# %%
df.isnull().sum().to_csv("missing_values.csv")

# %%
df_cols
# Out:
# ['Y/Pnt',
#  'Cmp%',
#  'RecYds',
#  'PaYds',
#  'Pick6',
#  'OROY',
#  'Rec',
#  'Pageviews',
#  'Sfty',
#  'FF',
#  'Pts',
#  'DROY',
#  'Ast',
#  'FR',
#  'PaDef',
#  'Blck',
#  'RuY/G',
#  'GWD',
#  'FG%',
#  'Scoop6',
#  'RetYds',
#  'DPOY',
#  'Tgt',
#  'RuAtt',
#  'PntYds',
#  'AP1',
#  'TFL',
#  'Y/Rec',
#  'Cmp',
#  'PaTD',
#  'SkD',
#  'MVP',
#  'QBWin',
#  'APYd',
#  'OPOY',
#  'Rate',
#  'GS',
#  'RecY/G',
#  'SB',
#  'IntO',
#  'FantPts',
#  'SkO',
#  'PaAtt',
#  'FG',
#  'IntD',
#  'RecTD',
#  'QBHit',
#  'Fmb',
#  'RuTD',
#  'RuY/A',
#  'Solo',
#  '2PM',
#  'G',
#  'RuYds']

# %%
# Select relevant features
features = df[df_cols]

# %%
# scaler = StandardScaler()
# scaled_features = scaler.fit_transform(features)

# %%
# Define numerical features (including Pageviews)
features = df_cols

# Apply StandardScaler to ALL numerical features
scaler = StandardScaler()
df[features] = scaler.fit_transform(df[features])

# Now, apply a custom weight ONLY to Pageviews after scaling
# df['Pageviews'] *= 1.9  # Increase its importance
# df['Pageviews'] *= 3.2  # Increase its importance
# df['Pageviews'] *= 2.92  # Increase its importance
# df['GS'] *= 1.23  # Increase its importance

# Prepare the final feature set for K-Means
scaled_features = df[features].values

# %%
wcss = []  # Within-cluster sum of squares

for k in range(1, 25):  # Test K from 1 to 10
    kmeans = KMeans(n_clusters=k, random_state=23, n_init=50)
    kmeans.fit(scaled_features)
    wcss.append(kmeans.inertia_)

# Plot the Elbow curve
plt.plot(range(1, 25), wcss, marker='o')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('WCSS')
plt.title('Elbow Method to Determine Optimal K')
plt.show()

# %%
kmeans = KMeans(n_clusters=10, random_state=23, n_init=50)
# kmeans = KMeans(n_clusters=6, random_state=23, n_init=50)
df['cluster'] = kmeans.fit_predict(scaled_features)

# %%
print(df.groupby('cluster').mean())
# Out:
#                   ID         G        GS        Cmp      PaAtt      Cmp%  \
# cluster
# 0        1261.278689  1.247613  1.507241  -0.137682  -0.137556 -0.984572
# 1        1214.125000  2.651262  3.708907  12.232352  12.214858  0.299661
# 2        1334.293739 -0.269888 -0.300951  -0.117206  -0.116677  0.017655
# 3        1111.378378  2.081519  2.490770  -0.139299  -0.139809  0.048793
# 4        1094.833333  2.870359 -0.731785  -0.138203  -0.138400 -0.463141
# 5        1078.428571  2.570834 -0.731785  -0.127084  -0.127427  1.781270
# 6        1292.905000  1.053461  1.255848  -0.139282  -0.139798  0.071708
# 7        1470.814815  0.419512  0.901340   4.222824   4.214720  0.288784
# 8        1027.000000  1.169352  1.864045   6.320575   6.252808  0.338413
# 9        1360.652174  0.492486  0.508189  -0.138370  -0.138844 -0.177733
#
#              PaYds       PaTD       IntO      Rate  ...      OPOY      DPOY  \
# cluster                                             ...
# 0        -0.135227  -0.126443  -0.134175 -0.362003  ...  0.561845 -0.053440
# 1        12.230816  12.025935  11.894804  1.015442  ... -0.053440 -0.053440
# 2        -0.117434  -0.117024  -0.113126 -0.027580  ... -0.053440 -0.042459
# 3        -0.138046  -0.132916  -0.141876  0.013716  ... -0.053440  1.975337
# 4        -0.137563  -0.118291  -0.141876  0.515736  ... -0.053440 -0.053440
# 5        -0.123325  -0.120380  -0.128455  1.895301  ... -0.053440 -0.053440
# 6        -0.137950  -0.132697  -0.141876  0.054813  ... -0.053440  0.040391
# 7         4.162196   3.801206   4.287448  0.772201  ... -0.053440 -0.053440
# 8         6.568575   7.940078   5.400868  1.818027  ...  3.074257 -0.053440
# 9        -0.137121  -0.125286  -0.139834  0.032683  ...  1.170442 -0.053440
#
#              OROY      DROY       AP1        SB  IG          Wiki  \
# cluster
# 0        0.204817 -0.065497  0.427292  0.168298 NaN  3.874857e+05
# 1        1.970730 -0.065497 -0.133017  0.543414 NaN  1.608086e+06
# 2       -0.061736 -0.038580 -0.091685 -0.058421 NaN  5.988149e+04
# 3       -0.061736  1.592176  1.652903  0.613869 NaN  2.432979e+05
# 4       -0.061736 -0.065497 -0.133017  0.060670 NaN  1.295012e+05
# 5       -0.061736 -0.065497  1.169033  0.005499 NaN  3.705629e+04
# 6       -0.061736  0.087838  0.140414  0.265353 NaN  8.877483e+04
# 7        2.347113 -0.065497 -0.133017  0.189401 NaN  1.184783e+06
# 8       -0.061736 -0.065497  5.183688  0.833061 NaN  1.924707e+06
# 9        0.645209 -0.065497  0.164190 -0.023286 NaN  4.072641e+05
#
#          Match Score  Pageviews
# cluster
# 0          98.347852   0.840364
# 1         100.000000   4.255637
# 2          98.669892  -0.152763
# 3          97.467804   0.447425
# 4          96.666667   0.044736
# 5          94.545455  -0.254356
# 6          98.745752  -0.074751
# 7          99.502269   3.384824
# 8         100.000000   7.565342
# 9          99.377597   0.845421
#
# [10 rows x 58 columns]
# C:\Users\Blair\AppData\Local\Temp\ipykernel_18104\3422288698.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   print(df.groupby('cluster').mean())

# %%
plt.scatter(df['Pageviews'], df['GS'], c=df['cluster'], cmap='viridis')
plt.xlabel('Wikipedia Page Views')
plt.ylabel('Games Started (GS)')
plt.title('K-Means Clustering of NFL Players')
plt.show()

# %%
for cluster in sorted(df['cluster'].unique()):
    print(f"\nCluster {cluster}:")
    print(df[df['cluster'] == cluster][['Player', 'Pageviews']].head(10))  # Show top 10 players per cluster
# Out:
# Cluster 0:
#               Player  Pageviews
# 6      Davante Adams   2.602082
# 17    Nelson Agholor   0.314409
# 21     Brandon Aiyuk   1.815278
# 39      Keenan Allen   0.956940
# 62      Mark Andrews  -0.293367
# 196  Kendrick Bourne  -0.083105
# 201       Tyler Boyd   0.191651
# 244       A.J. Brown   1.092885
# 254   Marquise Brown   0.918135
# 335         DJ Chark  -0.022631
#
# Cluster 1:
#                 Player  Pageviews
# 316         Derek Carr   1.545108
# 397       Kirk Cousins   5.245374
# 421        Andy Dalton   1.413965
# 608         Joe Flacco   4.911850
# 697         Jared Goff   6.761658
# 1531      Dak Prescott   3.101325
# 1750  Matthew Stafford   4.380289
# 2052    Russell Wilson   6.685526
#
# Cluster 2:
#                 Player  Pageviews
# 0    Israel Abanikanda  -0.203894
# 2       Yasir Abdullah  -0.313916
# 3      Micah Abernathy  -0.316103
# 4   Kris Abrams-Draine  -0.282104
# 7         Isaiah Adams  -0.283513
# 8        Matthew Adams  -0.310308
# 9     Montravius Adams  -0.288173
# 10         Myles Adams  -0.304331
# 11          Tony Adams  -0.299588
# 12      Jordan Addison   0.280944
#
# Cluster 3:
#                Player  Pageviews
# 37     Jonathan Allen  -0.098302
# 82       Denico Autry  -0.216281
# 114   Shaquil Barrett   0.258006
# 193         Joey Bosa   0.999727
# 194         Nick Bosa   2.744746
# 278  DeForest Buckner   0.086291
# 287       Brian Burns   0.391301
# 304   Calais Campbell   0.632524
# 358  Jadeveon Clowney   0.853655
# 404       Maxx Crosby   1.948834
#
# Cluster 4:
#                Player  Pageviews
# 195     Chris Boswell   0.043441
# 615         Nick Folk  -0.035081
# 660       Graham Gano  -0.155949
# 1070      Greg Joseph  -0.032479
# 1277  Brandon McManus   0.451564
# 1528      Matt Prater  -0.003077
#
# Cluster 5:
#              Player  Pageviews
# 63      Bryan Anger  -0.221801
# 93      Jake Bailey  -0.325749
# 500     Riley Dixon  -0.292624
# 807   Johnny Hekker  -0.211672
# 1210     Sam Martin  -0.309977
# 1418  Pat O'Donnell  -0.268653
# 1961      Tress Way  -0.150015
#
# Cluster 6:
#                    Player  Pageviews
# 14          Paulson Adebo  -0.267153
# 24        Azeez Al-Shaair   0.710814
# 25        Jaire Alexander   0.195084
# 26         Kwon Alexander  -0.047088
# 41             Zach Allen  -0.217624
# 67          Alex Anzalone   0.247894
# 68              Eli Apple   0.082672
# 72          Arik Armstead   0.328614
# 74  Dorance Armstrong Jr.  -0.247098
# 86         Chidobe Awuzie  -0.052276
#
# Cluster 7:
#                  Player  Pageviews
# 229   Teddy Bridgewater   1.462835
# 233     Jacoby Brissett   1.198191
# 288          Joe Burrow   4.545402
# 424      Jayden Daniels   6.603874
# 429         Sam Darnold   4.908000
# 599       Justin Fields   3.706092
# 667     Jimmy Garoppolo   3.575140
# 817      Justin Herbert   2.000358
# 899         Jalen Hurts   3.026177
# 1034       Daniel Jones   2.547734
#
# Cluster 8:
#                Player  Pageviews
# 38         Josh Allen   9.057993
# 935     Lamar Jackson  -0.240217
# 936     Lamar Jackson   6.973458
# 937     Lamar Jackson  -0.240217
# 938     Lamar Jackson   6.973458
# 1199  Patrick Mahomes  22.867578
#
# Cluster 9:
#              Player  Pageviews
# 1    Ameer Abdullah  -0.003717
# 5     De'Von Achane   0.216839
# 42   Tyler Allgeier  -0.129023
# 106  Saquon Barkley   4.491237
# 347      Nick Chubb   0.577581
# 382    James Conner   0.225564
# 385      James Cook   0.717484
# 495       AJ Dillon   0.163641
# 501    J.K. Dobbins   0.421861
# 544     Gus Edwards   0.053901

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

# Scatter plot
for cluster in sorted(df['cluster'].unique()):
    subset = df[df['cluster'] == cluster].tail(15)
    plt.scatter(subset['Pageviews'], subset['GS'], label=f'Cluster {cluster}')

    # Annotate player names
    for _, row in subset.iterrows():
        plt.annotate(row['Player'], (row['Pageviews'], row['GS']), fontsize=8, alpha=0.7)

# # Annotate player names
# for _, row in df.iterrows():
#     plt.annotate(row['Player'], (row['Pageviews'], row['PTS']), fontsize=8, alpha=0.7)


plt.xlabel("Wikipedia Page Views")
plt.ylabel("Games Started (GS)")
plt.title("K-Means Clustering of NBA Players")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))

color_list = [
    "blue",
    "orange",
    "green",
    "red",
    "purple",
    "brown",
    "pink",
    "gray",
    "lime",
    "cyan"
]

for cluster_num in range(10):

    subset = df[df['cluster'] == cluster_num].tail(15)

    plt.scatter(subset['Pageviews'], subset['GS'], label=f"Cluster {cluster_num}", color=color_list[cluster_num])

    for _, row in subset.iterrows():
        plt.annotate(row['Player'], (row['Pageviews'], row['GS']), fontsize=8, alpha=0.7)

    plt.xlabel("Wikipedia Page Views")
    plt.ylabel("Points Per Game (PPG)")
    plt.title(f"Cluster {cluster_num}: K-Means Clustering of NBA Players")
    plt.legend()
    plt.show()

# %%
# Find the average stats per cluster (fix this after normalization)
cluster_means = df.groupby('cluster')[['GS', 'Pageviews']].median()
print(cluster_means)
# Out:
#                GS  Pageviews
# cluster
# 0        1.091373   0.349092
# 1        3.656816   4.646069
# 2       -0.601559  -0.271215
# 3        2.237358   0.183698
# 4       -0.731785  -0.017778
# 5       -0.731785  -0.268653
# 6        1.052305  -0.171491
# 7        0.961147   2.547734
# 8        1.716456   6.973458
# 9        0.257929   0.418941

# %%
from scipy.spatial.distance import euclidean

# Find the centroid of the most "popular" cluster (highest Pageviews)
superstar_cluster = cluster_means['Pageviews'].idxmax()
superstar_centroid = cluster_means.loc[superstar_cluster].values

# Compute distance of each player from the superstar cluster
df['Obscurity_Score'] = df.apply(
    lambda row: euclidean(
        row[['GS', 'Pageviews']].values,
        superstar_centroid
    ), axis=1
)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 100))
df['Obscurity_Score'] = scaler.fit_transform(df[['Obscurity_Score']])

# Higher score = More obscure player
df = df.sort_values(by='Obscurity_Score', ascending=False)

# %%
print(df[['Player', 'Pageviews', 'GS', 'Obscurity_Score']].tail(25))
# Out:
#                    Player  Pageviews        GS  Obscurity_Score
# 1749    Amon-Ra St. Brown   3.836434  0.778832        20.590800
# 608            Joe Flacco   4.911850  4.242831        20.506828
# 2060       Jameis Winston   4.045081  1.534140        18.451925
# 1792       Tua Tagovailoa   4.185935  0.883012        18.297250
# 2052       Russell Wilson   6.685526  4.451192        17.293547
# 1402               Bo Nix   5.134657 -0.289018        17.111255
# 1994       Caleb Williams   5.255008 -0.289018        16.609119
# 288            Joe Burrow   4.545402  1.065328        15.809325
# 106        Saquon Barkley   4.491237  1.612275        15.624179
# 397          Kirk Cousins   5.245374  3.409388        15.213800
# 1461       Jonathan Owens   8.766759  0.179794        14.852002
# 942         Lamar Jackson   6.973458 -0.575514        14.413968
# 940         Lamar Jackson   6.973458 -0.575514        14.413968
# 429           Sam Darnold   4.908000  1.169508        13.437172
# 38             Josh Allen   9.057993  2.133177        13.368820
# 1182          Jordan Love   5.642039  0.127704        13.036099
# 424        Jayden Daniels   6.603874 -0.289018        12.824602
# 815         Derrick Henry   5.173811  2.002952        11.460320
# 1234  Christian McCaffrey   8.731087  1.560185        11.097157
# 1779          C.J. Stroud   6.577939  0.101659        10.455481
# 840           Tyreek Hill   6.192120  2.471764         6.834328
# 697            Jared Goff   6.761658  2.758260         6.685831
# 1230       Baker Mayfield   6.419017  1.950862         3.785638
# 936         Lamar Jackson   6.973458  1.716456         0.000000
# 938         Lamar Jackson   6.973458  1.716456         0.000000

# %%
print(df[['Player', 'Pageviews', 'PPG', 'Obscurity_Score']].head(25))
# Out:
#                  Player  Pageviews       PPG  Obscurity_Score
# 224      Daniss Jenkins  -1.535591 -1.520138       100.000000
# 243       Spencer Jones  -1.534877 -1.453080        99.919336
# 107         RayJ Dennis  -1.507774 -1.408375        99.891860
# 96      Isaiah Crawford  -1.514312 -1.408375        99.815813
# 292       Jaylen Martin  -1.481312 -1.352493        99.805283
# 120          Alex Ducas  -1.495075 -1.296612        99.770964
# 48        Jalen Bridges  -1.444280 -1.478227        99.676820
# 321         Riley Minix  -1.477090 -1.520138        99.674037
# 394        Liam Robbins  -1.462172 -1.404077        99.656360
# 138        Adam Flagler  -1.448824 -1.331538        99.619684
# 178     Elijah Harkless  -1.552676 -1.017204        99.568200
# 240         Isaac Jones  -1.474400 -0.941001        99.504374
# 78         Max Christie  -1.564493 -0.677352        99.490221
# 5        Trey Alexander  -1.394015 -1.376443        99.478719
# 466       Stanley Umude  -1.476592 -0.954337        99.472741
# 236         Colby Jones  -1.434589 -1.235458        99.457242
# 320       Justin Minaya  -1.446195 -1.216038        99.406955
# 307  JaQuori McLaughlin  -1.341981 -1.520138        99.403841
# 81         Jaylen Clark  -1.315832 -1.520138        99.393239
# 436         Tyler Smith  -1.373940 -1.184849        99.371056
# 144     Enrique Freeman  -1.392476 -1.222103        99.368849
# 234      Keshad Johnson  -1.403645 -1.259357        99.364330
# 322         Josh Minott  -1.392890 -1.132029        99.351242
# 68      Branden Carlson  -1.430901 -1.042995        99.340911
# 464        Hunter Tyson  -1.367667 -1.225904        99.316418

# %%
df.to_csv("players_with_obscurity_scores.csv", index=False)

# %%
import matplotlib.pyplot as plt

plt.hist(df['Obscurity_Score'], bins=100, edgecolor='black')
plt.xlabel("Obscurity Score")
plt.ylabel("Number of Players")
plt.title("Distribution of Player Obscurity Scores")
plt.show()
