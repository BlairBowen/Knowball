# %%
import pandas as pd

# %%
df = pd.read_csv("../merged_nba.csv")

# %%
# df = df.loc[df["Player_df2_x"] != "LeBron James"]

# %%
df
# Out:
#      Unnamed: 0.1  Unnamed: 0          Team_df2_x      Player_df2_x  \
# 0               0          24       Atlanta Hawks   Dominick Barlow
# 1               1          60       Atlanta Hawks       Kobe Bufkin
# 2               2          69       Atlanta Hawks      Clint Capela
# 3               3         106       Atlanta Hawks     Dyson Daniels
# 4               4         172       Atlanta Hawks    Mouhamed Gueye
# ..            ...         ...                 ...               ...
# 506           506         366  Washington Wizards      Jordan Poole
# 507           507         406  Washington Wizards         Alex Sarr
# 508           508         426  Washington Wizards      Marcus Smart
# 509           509         450  Washington Wizards           JT Thor
# 510           510         470  Washington Wizards  Tristan Vukčević
#
#                                         Wikipedia_Link  Pageviews   ID  \
# 0        https://en.wikipedia.org/wiki/Dominick_Barlow    37369.0   37
# 1            https://en.wikipedia.org/wiki/Kobe_Bufkin    61452.0  107
# 2           https://en.wikipedia.org/wiki/Clint_Capela   130402.0  124
# 3          https://en.wikipedia.org/wiki/Dyson_Daniels   301712.0  183
# 4         https://en.wikipedia.org/wiki/Mouhamed_Gueye    37505.0  300
# ..                                                 ...        ...  ...
# 506         https://en.wikipedia.org/wiki/Jordan_Poole   392527.0  626
# 507            https://en.wikipedia.org/wiki/Alex_Sarr   186572.0  686
# 508         https://en.wikipedia.org/wiki/Marcus_Smart   359563.0  720
# 509              https://en.wikipedia.org/wiki/JT_Thor   153500.0  763
# 510  https://en.wikipedia.org/wiki/Tristan_Vuk%C4%8...   111985.0  791
#
#          Player_df1_x    Until    G  ...  All_NBA  Champ         IG  \
# 0     Dominick Barlow  2024-25   68  ...        0      0    17017.0
# 1         Kobe Bufkin  2024-25   27  ...        0      0    45143.0
# 2        Clint Capela  2024-25  650  ...        0      0   618403.0
# 3       Dyson Daniels  2024-25  157  ...        0      0   131450.0
# 4    Mouhamadou Gueye  2023-24   11  ...        0      0        0.0
# ..                ...      ...  ...  ...      ...    ...        ...
# 506      Jordan Poole  2024-25  378  ...        0      1  2226133.0
# 507         Alex Sarr  2024-25   37  ...        0      0   124044.0
# 508      Marcus Smart  2024-25  619  ...        0      0   819290.0
# 509           JT Thor  2024-25  172  ...        0      0        0.0
# 510  Tristan Vukcevic  2024-25   14  ...        0      0    62369.0
#
#          Player_df1_y      Player_df2_y  Match Score          Team_df2_y  \
# 0     Dominick Barlow   Dominick Barlow   100.000000       Atlanta Hawks
# 1         Kobe Bufkin       Kobe Bufkin   100.000000       Atlanta Hawks
# 2        Clint Capela      Clint Capela   100.000000       Atlanta Hawks
# 3       Dyson Daniels     Dyson Daniels   100.000000       Atlanta Hawks
# 4    Mouhamadou Gueye    Mouhamed Gueye    86.666667       Atlanta Hawks
# ..                ...               ...          ...                 ...
# 506      Jordan Poole      Jordan Poole   100.000000  Washington Wizards
# 507         Alex Sarr         Alex Sarr   100.000000  Washington Wizards
# 508      Marcus Smart      Marcus Smart   100.000000  Washington Wizards
# 509           JT Thor           JT Thor   100.000000  Washington Wizards
# 510  Tristan Vukcevic  Tristan Vukčević    87.500000  Washington Wizards
#
#      df2_index  df1_index  Team_Pageviews
# 0            0         36          460240
# 1            1        106          460240
# 2            2        123          460240
# 3            3        182          460240
# 4            4        299          460240
# ..         ...        ...             ...
# 506        531        625          551729
# 507        532        685          551729
# 508        533        719          551729
# 509        534        762          551729
# 510        535        790          551729
#
# [511 rows x 51 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Team_df2_x', 'Player_df2_x',
#        'Wikipedia_Link', 'Pageviews', 'ID', 'Player_df1_x', 'Until', 'G', 'GS',
#        'All_Star', 'MP', 'FG', 'FGA', '2P', '2PA', '3P', '3PA', 'FT', 'FTA',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'FG%',
#        '2P%', '3P%', 'FT%', 'TS%', 'eFG%', 'Pos', 'Team_df1', 'MVP', 'ROY',
#        'DPOY', 'All_NBA', 'Champ', 'IG', 'Player_df1_y', 'Player_df2_y',
#        'Match Score', 'Team_df2_y', 'df2_index', 'df1_index',
#        'Team_Pageviews'],
#       dtype='object')

# %%
drop_columns = [
    'Unnamed: 0.1', 
    'Unnamed: 0', 
    # 'Team_df2_x', 
    # 'Player_df1_y',
    'Player_df2_x',
    'Wikipedia_Link',
    'ID', 
    'Player_df1_x', 
    'Until',
    'Pos', 
    'Team_df1',
    'Player_df2_y', 
    'Match Score', 
    'Team_df2_y', 
    'df2_index', 
    'df1_index',
    ]

# %%
df_dropped = df.drop(drop_columns, axis=1)

# %%
df_dropped
# Out:
#              Team_df2_x  Pageviews    G   GS  All_Star     MP    FG   FGA  \
# 0         Atlanta Hawks    37369.0   68    1         0    858   104   206
# 1         Atlanta Hawks    61452.0   27    0         0    320    52   139
# 2         Atlanta Hawks   130402.0  650  587         0  17161  3423  5539
# 3         Atlanta Hawks   301712.0  157   64         0   3643   434   971
# 4         Atlanta Hawks    37505.0   11    0         0    120    11    38
# ..                  ...        ...  ...  ...       ...    ...   ...   ...
# 506  Washington Wizards   392527.0  378  215         0  10399  2123  5047
# 507  Washington Wizards   186572.0   37   37         0   1000   161   402
# 508  Washington Wizards   359563.0  619  386         0  18428  2220  5728
# 509  Washington Wizards   153500.0  172   11         0   2045   208   488
# 510  Washington Wizards   111985.0   14    4         0    163    30    71
#
#        2P   2PA  ...    TS%   eFG%  MVP  ROY  DPOY  All_NBA  Champ         IG  \
# 0     100   191  ...  0.550  0.515    0    0     0        0      0    17017.0
# 1      39    80  ...  0.445  0.421    0    0     0        0      0    45143.0
# 2    3423  5534  ...  0.618  0.618    0    0     0        0      0   618403.0
# 3     321   611  ...  0.517  0.505    0    0     0        0      0   131450.0
# 4      11    35  ...  0.310  0.289    0    0     0        0      0        0.0
# ..    ...   ...  ...    ...    ...  ...  ...   ...      ...    ...        ...
# 506  1218  2416  ...  0.559  0.510    0    0     0        0      1  2226133.0
# 507   106   229  ...  0.491  0.469    0    0     0        0      0   124044.0
# 508  1238  2688  ...  0.516  0.473    0    0     1        0      0   819290.0
# 509   131   253  ...  0.525  0.505    0    0     0        0      0        0.0
# 510    20    32  ...  0.539  0.493    0    0     0        0      0    62369.0
#
#          Player_df1_y  Team_Pageviews
# 0     Dominick Barlow          460240
# 1         Kobe Bufkin          460240
# 2        Clint Capela          460240
# 3       Dyson Daniels          460240
# 4    Mouhamadou Gueye          460240
# ..                ...             ...
# 506      Jordan Poole          551729
# 507         Alex Sarr          551729
# 508      Marcus Smart          551729
# 509           JT Thor          551729
# 510  Tristan Vukcevic          551729
#
# [511 rows x 37 columns]

# %%
df_dropped = df_dropped.rename(columns={
    "Player_df1_y": "Player", 
    "Team_df2_x": "Team"
    })

# %%
players = df_dropped.copy()

# %%
total_columns = [
    'MP', 
    'FG', 
    'FGA', 
    '2P', 
    '2PA', 
    '3P', 
    '3PA', 
    'FT', 
    'FTA',
    'ORB', 
    'DRB', 
    'TRB', 
    'AST', 
    'STL', 
    'BLK', 
    'TOV', 
    'PF', 
    'PTS',
]

# %%
def per_game(stat, games_played):
    return stat / games_played if games_played > 0 else 0

# %%
def per_gamify_cols(df, columns, games_column):
    for column in columns:
        df[column + "_PerGame"] = df.apply(lambda row: per_game(row[column], row[games_column]), axis=1)
    return df

# %%
players = per_gamify_cols(players, total_columns, 'G')

# %%
players
# Out:
#                    Team  Pageviews    G   GS  All_Star     MP    FG   FGA  \
# 0         Atlanta Hawks    37369.0   68    1         0    858   104   206
# 1         Atlanta Hawks    61452.0   27    0         0    320    52   139
# 2         Atlanta Hawks   130402.0  650  587         0  17161  3423  5539
# 3         Atlanta Hawks   301712.0  157   64         0   3643   434   971
# 4         Atlanta Hawks    37505.0   11    0         0    120    11    38
# ..                  ...        ...  ...  ...       ...    ...   ...   ...
# 506  Washington Wizards   392527.0  378  215         0  10399  2123  5047
# 507  Washington Wizards   186572.0   37   37         0   1000   161   402
# 508  Washington Wizards   359563.0  619  386         0  18428  2220  5728
# 509  Washington Wizards   153500.0  172   11         0   2045   208   488
# 510  Washington Wizards   111985.0   14    4         0    163    30    71
#
#        2P   2PA  ...  FTA_PerGame  ORB_PerGame  DRB_PerGame  TRB_PerGame  \
# 0     100   191  ...     1.014706     1.338235     1.882353     3.220588
# 1      39    80  ...     0.962963     0.407407     1.592593     2.000000
# 2    3423  5534  ...     2.832308     3.670769     6.918462    10.589231
# 3     321   611  ...     0.929936     1.012739     2.859873     3.872611
# 4      11    35  ...     0.818182     1.090909     1.000000     2.090909
# ..    ...   ...  ...          ...          ...          ...          ...
# 506  1218  2416  ...     3.423280     0.359788     2.298942     2.658730
# 507   106   229  ...     2.270270     1.891892     4.810811     6.702703
# 508  1238  2688  ...     2.436187     0.809370     2.668821     3.478191
# 509   131   253  ...     0.552326     0.540698     1.476744     2.017442
# 510    20    32  ...     1.571429     0.500000     2.142857     2.642857
#
#      AST_PerGame  STL_PerGame  BLK_PerGame  TOV_PerGame  PF_PerGame  \
# 0       0.897059     0.338235     0.485294     0.352941    1.544118
# 1       1.629630     0.370370     0.259259     0.666667    1.074074
# 2       1.023077     0.678462     1.443077     1.069231    2.361538
# 3       2.738854     1.535032     0.420382     1.165605    1.847134
# 4       0.454545     0.272727     1.636364     1.090909    1.363636
# ..           ...          ...          ...          ...         ...
# 506     3.730159     0.849206     0.272487     2.314815    2.526455
# 507     2.216216     0.648649     1.540541     1.486486    2.486486
# 508     4.612278     1.579968     0.363489     1.903069    2.565428
# 509     0.488372     0.250000     0.372093     0.424419    0.906977
# 510     0.928571     0.357143     0.571429     0.714286    2.142857
#
#      PTS_PerGame
# 0       3.823529
# 1       4.962963
# 2      12.072308
# 3       6.821656
# 4       2.363636
# ..           ...
# 506    16.624339
# 507    11.648649
# 508    10.654281
# 509     3.232558
# 510     6.214286
#
# [511 rows x 55 columns]

# %%
features = [x for x in players.columns if x not in ['Player', 'Team']]
# drop_features = [

# ]
# features = [x for x in df.columns if x not in set(drop_features)]

# %%
features
# Out:
# ['Pageviews',
#  'G',
#  'GS',
#  'All_Star',
#  'MP',
#  'FG',
#  'FGA',
#  '2P',
#  '2PA',
#  '3P',
#  '3PA',
#  'FT',
#  'FTA',
#  'ORB',
#  'DRB',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'PF',
#  'PTS',
#  'FG%',
#  '2P%',
#  '3P%',
#  'FT%',
#  'TS%',
#  'eFG%',
#  'MVP',
#  'ROY',
#  'DPOY',
#  'All_NBA',
#  'Champ',
#  'IG',
#  'Team_Pageviews',
#  'MP_PerGame',
#  'FG_PerGame',
#  'FGA_PerGame',
#  '2P_PerGame',
#  '2PA_PerGame',
#  '3P_PerGame',
#  '3PA_PerGame',
#  'FT_PerGame',
#  'FTA_PerGame',
#  'ORB_PerGame',
#  'DRB_PerGame',
#  'TRB_PerGame',
#  'AST_PerGame',
#  'STL_PerGame',
#  'BLK_PerGame',
#  'TOV_PerGame',
#  'PF_PerGame',
#  'PTS_PerGame']

# %%
players = players.fillna(players[features].median())

# %%
data = players[features].copy()

# %%
data
# Out:
#      Pageviews    G   GS  All_Star     MP    FG   FGA    2P   2PA   3P  ...  \
# 0      37369.0   68    1         0    858   104   206   100   191    4  ...
# 1      61452.0   27    0         0    320    52   139    39    80   13  ...
# 2     130402.0  650  587         0  17161  3423  5539  3423  5534    0  ...
# 3     301712.0  157   64         0   3643   434   971   321   611  113  ...
# 4      37505.0   11    0         0    120    11    38    11    35    0  ...
# ..         ...  ...  ...       ...    ...   ...   ...   ...   ...  ...  ...
# 506   392527.0  378  215         0  10399  2123  5047  1218  2416  905  ...
# 507   186572.0   37   37         0   1000   161   402   106   229   55  ...
# 508   359563.0  619  386         0  18428  2220  5728  1238  2688  982  ...
# 509   153500.0  172   11         0   2045   208   488   131   253   77  ...
# 510   111985.0   14    4         0    163    30    71    20    32   10  ...
#
#      FTA_PerGame  ORB_PerGame  DRB_PerGame  TRB_PerGame  AST_PerGame  \
# 0       1.014706     1.338235     1.882353     3.220588     0.897059
# 1       0.962963     0.407407     1.592593     2.000000     1.629630
# 2       2.832308     3.670769     6.918462    10.589231     1.023077
# 3       0.929936     1.012739     2.859873     3.872611     2.738854
# 4       0.818182     1.090909     1.000000     2.090909     0.454545
# ..           ...          ...          ...          ...          ...
# 506     3.423280     0.359788     2.298942     2.658730     3.730159
# 507     2.270270     1.891892     4.810811     6.702703     2.216216
# 508     2.436187     0.809370     2.668821     3.478191     4.612278
# 509     0.552326     0.540698     1.476744     2.017442     0.488372
# 510     1.571429     0.500000     2.142857     2.642857     0.928571
#
#      STL_PerGame  BLK_PerGame  TOV_PerGame  PF_PerGame  PTS_PerGame
# 0       0.338235     0.485294     0.352941    1.544118     3.823529
# 1       0.370370     0.259259     0.666667    1.074074     4.962963
# 2       0.678462     1.443077     1.069231    2.361538    12.072308
# 3       1.535032     0.420382     1.165605    1.847134     6.821656
# 4       0.272727     1.636364     1.090909    1.363636     2.363636
# ..           ...          ...          ...         ...          ...
# 506     0.849206     0.272487     2.314815    2.526455    16.624339
# 507     0.648649     1.540541     1.486486    2.486486    11.648649
# 508     1.579968     0.363489     1.903069    2.565428    10.654281
# 509     0.250000     0.372093     0.424419    0.906977     3.232558
# 510     0.357143     0.571429     0.714286    2.142857     6.214286
#
# [511 rows x 53 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.cluster import KMeans

# %%
scaler = StandardScaler()
# scaler = RobustScaler()

# %%
data[features] = scaler.fit_transform(data[features])

# %%
data.columns
# Out:
# Index(['Pageviews', 'G', 'GS', 'All_Star', 'MP', 'FG', 'FGA', '2P', '2PA',
#        '3P', '3PA', 'FT', 'FTA', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK',
#        'TOV', 'PF', 'PTS', 'FG%', '2P%', '3P%', 'FT%', 'TS%', 'eFG%', 'MVP',
#        'ROY', 'DPOY', 'All_NBA', 'Champ', 'IG', 'Team_Pageviews', 'MP_PerGame',
#        'FG_PerGame', 'FGA_PerGame', '2P_PerGame', '2PA_PerGame', '3P_PerGame',
#        '3PA_PerGame', 'FT_PerGame', 'FTA_PerGame', 'ORB_PerGame',
#        'DRB_PerGame', 'TRB_PerGame', 'AST_PerGame', 'STL_PerGame',
#        'BLK_PerGame', 'TOV_PerGame', 'PF_PerGame', 'PTS_PerGame'],
#       dtype='object')

# %%
data["Pageviews"] *= 3
data["G"] *= 1
data["GS"] *= 1.2
data["All_Star"] *= 2
data["MP"] *= 1
data["FG"] *= 1
data["FGA"] *= 1
data["2P"] *= 1
data["2PA"] *= 1
data["3P"] *= 1
data["3PA"] *= 1
data["FT"] *= 1
data["FTA"] *= 1
data["ORB"] *= 1
data["DRB"] *= 1
data["TRB"] *= 1
data["AST"] *= 1
data["STL"] *= 1
data["BLK"] *= 1
data["TOV"] *= 1
data["PF"] *= 1
data["PTS"] *= 1
data["FG%"] *= 1
data["2P%"] *= 1
data["3P%"] *= 1
data["FT%"] *= 1
data["TS%"] *= 1
data["eFG%"] *= 1
data["MVP"] *= 1
data["ROY"] *= 1
data["DPOY"] *= 1
data["All_NBA"] *= 1
data["Champ"] *= 1
data["IG"] *= 1
data["Team_Pageviews"] *= 1
data["MP_PerGame"] *= 1
data["FG_PerGame"] *= 1
data["FGA_PerGame"] *= 1
data["2P_PerGame"] *= 1
data["2PA_PerGame"] *= 1
data["3P_PerGame"] *= 1
data["3PA_PerGame"] *= 1
data["FT_PerGame"] *= 1
data["FTA_PerGame"] *= 1
data["ORB_PerGame"] *= 1
data["DRB_PerGame"] *= 1
data["TRB_PerGame"] *= 1
data["AST_PerGame"] *= 1
data["STL_PerGame"] *= 1
data["BLK_PerGame"] *= 1
data["TOV_PerGame"] *= 1
data["PF_PerGame"] *= 1
data["PTS_PerGame"] *= 1

# %%
scaled_features = data[features].values

# %%
import matplotlib.pyplot as plt

# %%
wcss = []  # Within-cluster sum of squares

for k in range(1, 25):  # Test K from 1 to 10
    kmeans = KMeans(n_clusters=k, random_state=23, n_init=50)
    kmeans.fit(scaled_features)
    wcss.append(kmeans.inertia_)

# Plot the Elbow curve
plt.plot(range(1, 25), wcss, marker='o')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('WCSS')
plt.title('Elbow Method to Determine Optimal K')
plt.show()

# %%
kmeans = KMeans(n_clusters=10, random_state=23, n_init=50)
data['cluster'] = kmeans.fit_predict(scaled_features)

# %%
print(data.groupby('cluster').mean())
# Out:
#          Pageviews         G        GS   All_Star        MP        FG  \
# cluster
# 0        -1.101859 -0.742986 -0.786179  -0.545207 -0.722603 -0.653214
# 1         0.632079  0.566164  0.644335  -0.202187  0.620486  0.549478
# 2        36.538089  4.325940  6.562527  20.722036  5.662823  7.530163
# 3         5.460517  2.572143  3.851680   9.497657  3.140380  3.608495
# 4        -0.360242  0.017882 -0.182044  -0.545207 -0.139643 -0.163293
# 5        13.855004  0.880566  1.751633   5.170364  1.205393  1.804247
# 6        -0.609019  0.009908 -0.297090  -0.545207 -0.103743 -0.215105
# 7        -0.756633 -0.968765 -0.828654  -0.545207 -0.827035 -0.724297
# 8         0.593286  1.786984  2.304627   0.768358  1.637620  1.412899
# 9         2.017544  1.677683  2.356006   2.042307  1.881026  1.844924
#
#               FGA        2P       2PA        3P  ...  FTA_PerGame  \
# cluster                                          ...
# 0       -0.656433 -0.611314 -0.611172 -0.605785  ...    -0.681547
# 1        0.618260  0.414695  0.457187  0.788698  ...     0.781029
# 2        7.009660  8.064520  7.614433  4.130591  ...     3.595468
# 3        3.634269  3.685405  3.793816  2.481781  ...     2.984043
# 4       -0.249399 -0.030293 -0.105627 -0.495012  ...     0.151482
# 5        1.753913  1.590072  1.536713  1.949294  ...     2.504990
# 6       -0.184921 -0.283615 -0.272080  0.031314  ...    -0.181462
# 7       -0.727015 -0.673691 -0.669481 -0.683336  ...    -0.920080
# 8        1.125356  1.862346  1.673234 -0.204121  ...     0.913749
# 9        1.929444  1.668892  1.763893  1.872743  ...     1.422145
#
#          ORB_PerGame  DRB_PerGame  TRB_PerGame  AST_PerGame  STL_PerGame  \
# cluster
# 0          -0.448328    -0.733896    -0.686850    -0.631296    -0.741240
# 1           0.001439     0.577213     0.426782     0.998143     0.848805
# 2           0.305638     2.115948     1.661513     3.235953     2.305930
# 3           0.288999     1.615339     1.286400     2.191821     1.922208
# 4           1.593499     0.864730     1.153374    -0.333146    -0.053958
# 5           0.610307     2.176090     1.804342     1.995016     1.574824
# 6          -0.276807    -0.144362    -0.196032     0.104492     0.286998
# 7          -0.867097    -1.124331    -1.110480    -0.955760    -1.106707
# 8           2.379689     2.022370     2.262322    -0.010177     0.241958
# 9           0.118809     0.812198     0.638246     1.238202     1.070830
#
#          BLK_PerGame  TOV_PerGame  PF_PerGame  PTS_PerGame
# cluster
# 0          -0.422450    -0.727067   -0.759779    -0.814352
# 1           0.007540     0.986202    0.687369     1.065725
# 2           0.708027     3.064092    0.148426     3.013356
# 3           0.743105     2.228339    0.962990     2.299497
# 4           1.357790     0.017033    0.880339     0.076040
# 5           1.448147     2.535523    0.925663     2.574532
# 6          -0.276001    -0.024391    0.139919     0.032569
# 7          -0.675533    -1.057474   -1.411158    -1.268618
# 8           1.776769     0.599959    1.219165     0.560207
# 9           0.155184     1.344972    0.775288     1.510711
#
# [10 rows x 53 columns]

# %%
plt.scatter(data['Pageviews'], data['PTS_PerGame'], c=data['cluster'], cmap='viridis')
plt.xlabel('Wikipedia Page Views')
plt.ylabel('Points Per Game (PPG)')
plt.title('K-Means Clustering of NBA Players')
plt.show()

# %%
# data['cluster'] = kmeans.fit_predict(data)

# %%
for cluster in sorted(data['cluster'].unique()):
    print(f"\nCluster {cluster}:")
    print(df.loc[data[data['cluster'] == cluster].index][['Player_df2_x', 'Pageviews']].head(10))
# Out:
# Cluster 0:
#           Player_df2_x  Pageviews
# 0      Dominick Barlow    37369.0
# 1          Kobe Bufkin    61452.0
# 14        Jacob Toppin   197531.0
# 15      Keaton Wallace    28586.0
# 19          JD Davison    79655.0
# 23         Luke Kornet   227690.0
# 24       Drew Peterson    88362.0
# 27       Neemias Queta   201086.0
# 30  Xavier Tillman Sr.   176181.0
# 31        Jordan Walsh   161658.0
#
# Cluster 1:
#        Player_df2_x  Pageviews
# 6      Caris LeVert   121715.0
# 32    Derrick White   165415.0
# 49      LaMelo Ball  1132946.0
# 50    Miles Bridges   300167.0
# 58   Brandon Miller   271759.0
# 67       Lonzo Ball   929933.0
# 72      Josh Giddey   885430.0
# 81       Coby White   237802.0
# 85   Darius Garland   270265.0
# 87  De'Andre Hunter   117928.0
#
# Cluster 2:
#      Player_df2_x  Pageviews
# 222  LeBron James  8373555.0
#
# Cluster 3:
#               Player_df2_x  Pageviews
# 100          Anthony Davis  1149289.0
# 132      Russell Westbrook  1529687.0
# 208           James Harden  1298340.0
# 269  Giannis Antetokounmpo  2382282.0
# 275         Damian Lillard   996490.0
# 378            Paul George  1154406.0
# 395           Kevin Durant  3017983.0
# 428          DeMar DeRozan   969331.0
# 454             Chris Paul  1446349.0
#
# Cluster 4:
#         Player_df2_x  Pageviews
# 5      Jalen Johnson   186152.0
# 9    Larry Nance Jr.   173930.0
# 11    Onyeka Okongwu   110792.0
# 12   Daeqwon Plowden    27748.0
# 34       Nic Claxton    98006.0
# 43    Day'Ron Sharpe    48059.0
# 70      Zach Collins    86069.0
# 78       Jalen Smith   140357.0
# 91       Evan Mobley   264940.0
# 104   Daniel Gafford   405184.0
#
# Cluster 5:
#           Player_df2_x  Pageviews
# 29        Jayson Tatum  2805655.0
# 106       Kyrie Irving  2957736.0
# 121       Nikola Jokić  3156198.0
# 151      Stephen Curry  4915516.0
# 217        Luka Dončić  3572995.0
# 292    Anthony Edwards  4199531.0
# 377        Joel Embiid  2267283.0
# 457  Victor Wembanyama  3266396.0
#
# Cluster 6:
#           Player_df2_x  Pageviews
# 3        Dyson Daniels   301712.0
# 7         Terance Mann   102410.0
# 8     Garrison Mathews    39986.0
# 13  Zaccharie Risacher   747756.0
# 18        Torrey Craig   107679.0
# 20          Sam Hauser   249726.0
# 26    Payton Pritchard   539468.0
# 35        Noah Clowney    51379.0
# 37     Cameron Johnson   135504.0
# 38        Keon Johnson    58927.0
#
# Cluster 7:
#           Player_df2_x  Pageviews
# 4       Mouhamed Gueye    37505.0
# 10       Georges Niang   223704.0
# 28   Baylor Scheierman   137343.0
# 39       Maxwell Lewis    61353.0
# 63          KJ Simpson    29274.0
# 66       Mark Williams    63660.0
# 74       Kevin Huerter    90581.0
# 84         Emoni Bates   166982.0
# 116     Trey Alexander    39449.0
# 120            PJ Hall    59759.0
#
# Cluster 8:
#          Player_df2_x  Pageviews
# 2        Clint Capela   130402.0
# 22         Al Horford  1187414.0
# 54         Taj Gibson   221248.0
# 60       Jusuf Nurkić   226532.0
# 80     Nikola Vučević   219835.0
# 83      Jarrett Allen   198404.0
# 95   Tristan Thompson   807390.0
# 123    DeAndre Jordan   398669.0
# 165      Steven Adams   512197.0
# 197      Myles Turner   241653.0
#
# Cluster 9:
#            Player_df2_x  Pageviews
# 16           Trae Young   640276.0
# 17         Jaylen Brown  1920374.0
# 21         Jrue Holiday  1420294.0
# 25   Kristaps Porziņģis  1232667.0
# 42     D'Angelo Russell   728815.0
# 90     Donovan Mitchell   794537.0
# 113       Klay Thompson  1706759.0
# 139       Tobias Harris   356689.0
# 146     Dennis Schröder   733735.0
# 150    Jimmy Butler III  1205216.0

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

# Scatter plot
for cluster in sorted(data['cluster'].unique()):
    subset = data[data['cluster'] == cluster].tail(15)
    names = df.loc[data[data['cluster'] == cluster].index].tail(15)
    plt.scatter(subset['Pageviews'], subset['PTS_PerGame'], label=f'Cluster {cluster}')

    # Annotate player names
    for index, row in subset.iterrows():
        plt.annotate(df.loc[index]['Player_df2_x'], (row['Pageviews'], row['PTS_PerGame']), fontsize=8, alpha=0.7)

# # Annotate player names
# for _, row in df.iterrows():
#     plt.annotate(row['Player'], (row['Pageviews'], row['PTS']), fontsize=8, alpha=0.7)


plt.xlabel("Wikipedia Page Views")
plt.ylabel("Points Per Game (PPG)")
plt.title("K-Means Clustering of NBA Players")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import PCA

# Apply PCA to reduce to 2D for visualization
pca = PCA(n_components=2)
X_pca = pca.fit_transform(scaled_features)

# Add PCA results to DataFrame
data['PCA1'] = X_pca[:, 0]
data['PCA2'] = X_pca[:, 1]

# Plot the PCA results
plt.figure(figsize=(10, 6))

# Scatter plot for each cluster
for cluster in sorted(data['cluster'].unique()):
    # subset = data[data['cluster'] == cluster]
    subset = data[data['cluster'] == cluster].tail(15)
    plt.scatter(subset['PCA1'], subset['PCA2'], label=f'Cluster {cluster}')

    # Annotate player names
    for index, row in subset.iterrows():
        plt.annotate(df.loc[index]['Player_df2_x'], (row['PCA1'], row['PCA2']), fontsize=8, alpha=0.7)

plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA Visualization of NBA Player Clusters")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))

color_list = [
    "blue",
    "orange",
    "green",
    "red",
    "purple",
    "brown",
    "pink",
    "gray",
    "lime",
    "cyan"
]

for cluster_num in range(10):

    subset = data[data['cluster'] == cluster_num].tail(15)

    # plt.scatter(subset['Pageviews'], subset['PTS_PerGame'], label=f"Cluster {cluster_num}", c=cluster_num)
    plt.scatter(subset['Pageviews'], subset['PTS_PerGame'], label=f"Cluster {cluster_num}", color=color_list[cluster_num])

    for index, row in subset.iterrows():
        plt.annotate(df.loc[index]['Player_df2_x'], (row['Pageviews'], row['PTS_PerGame']), fontsize=8, alpha=0.7)

    plt.xlabel("Wikipedia Page Views")
    plt.ylabel("Points Per Game (PPG)")
    plt.title(f"Cluster {cluster_num}: K-Means Clustering of NBA Players")
    plt.legend()
    plt.show()

# %%
data_w_names = pd.merge(data, df["Player_df2_x"], left_index=True, right_index=True, how="inner")

# %%
cluster_means = data.groupby('cluster')[data.columns].median()
# cluster_means = data.groupby('cluster')[['PTS_PerGame', 'AST_PerGame', 'TRB_PerGame', 'Pageviews']].median()
print(cluster_means)
# Out:
#          Pageviews         G        GS   All_Star        MP        FG  \
# cluster
# 0        -1.274137 -0.834271 -0.821157  -0.545207 -0.769418 -0.685748
# 1         0.115331  0.542135  0.522432  -0.545207  0.633189  0.540271
# 2        36.538089  4.325940  6.562527  20.722036  5.662823  7.530163
# 3         4.317409  2.801253  3.512218   9.025052  3.488875  3.564236
# 4        -0.822401 -0.049249 -0.363611  -0.545207 -0.202716 -0.239799
# 5        13.029056  0.732284  1.585198   5.303285  1.055380  1.612290
# 6        -0.901784 -0.077161 -0.416870  -0.545207 -0.171950 -0.235718
# 7        -1.315856 -0.980808 -0.830840  -0.545207 -0.831512 -0.726017
# 8         0.220288  1.778980  2.011273   0.518155  1.433163  1.147567
# 9         1.341738  1.639421  2.359880   1.581517  1.837725  1.860977
#
#               FGA        2P       2PA        3P  ...  TRB_PerGame  \
# cluster                                          ...
# 0       -0.689412 -0.643320 -0.639696 -0.650916  ...    -0.764943
# 1        0.610517  0.391227  0.426460  0.716471  ...     0.288259
# 2        7.009660  8.064520  7.614433  4.130591  ...     1.661513
# 3        3.679166  3.878085  3.722558  2.773834  ...     1.140283
# 4       -0.319314 -0.133283 -0.186194 -0.602599  ...     1.090136
# 5        1.657643  1.598084  1.589885  1.478923  ...     1.871989
# 6       -0.227209 -0.326959 -0.320303 -0.123288  ...    -0.252325
# 7       -0.730232 -0.675714 -0.672361 -0.687638  ...    -1.183114
# 8        0.766953  1.682860  1.376109 -0.591002  ...     2.292326
# 9        1.875568  1.637715  1.750307  1.836473  ...     0.316982
#
#          AST_PerGame  STL_PerGame  BLK_PerGame  TOV_PerGame  PF_PerGame  \
# cluster
# 0          -0.672377    -0.805072    -0.531396    -0.784318   -0.789981
# 1           0.946889     0.781798    -0.178020     0.781220    0.607700
# 2           3.235953     2.305930     0.708027     3.064092    0.148426
# 3           1.753313     1.811800     0.002848     2.201893    0.939956
# 4          -0.409106    -0.122707     1.110513    -0.093636    0.902745
# 5           1.731992     1.567791     0.446933     2.431656    0.812099
# 6          -0.058556     0.121130    -0.383020    -0.142208    0.062630
# 7          -1.016344    -1.422599    -0.957567    -1.169201   -1.763750
# 8          -0.305634     0.130618     1.577151     0.419971    1.034758
# 9           1.142206     0.802789    -0.042289     1.275629    0.606051
#
#          PTS_PerGame  cluster       PCA1       PCA2
# cluster
# 0          -0.782187      0.0  -4.120487   1.067955
# 1           1.011071      1.0   3.344941  -1.410769
# 2           3.013356      2.0  50.169681  27.452956
# 3           2.456080      3.0  20.932326   1.122838
# 4          -0.022714      4.0  -0.431810  -2.262848
# 5           2.424532      5.0  16.925681   5.494358
# 6          -0.068730      6.0  -1.090051  -0.179096
# 7          -1.308962      7.0  -5.688067   3.360427
# 8           0.597561      8.0   7.126261  -5.141648
# 9           1.570815      9.0   9.102488  -1.942515
#
# [10 rows x 56 columns]

# %%
from scipy.spatial.distance import euclidean

# Find the centroid of the most "popular" cluster (highest Pageviews)
superstar_cluster = cluster_means['Pageviews'].idxmax()
superstar_centroid = cluster_means.loc[superstar_cluster].values

# Compute distance of each player from the superstar cluster
data_w_names['Obscurity_Score'] = data_w_names.apply(
    lambda row: euclidean(
        row[cluster_means.columns].values,
        # row[['PTS_PerGame', 'AST_PerGame', 'TRB_PerGame', 'Pageviews']].values,
        superstar_centroid
    ), axis=1
)

# %%
# from scipy.spatial.distance import mahalanobis
# import numpy as np

# # Select only the relevant feature columns
# feature_cols = ['PTS_PerGame', 'AST_PerGame', 'TRB_PerGame', 'Pageviews']

# # Compute covariance matrix and inverse
# cov_matrix = np.cov(cluster_means[feature_cols].T)
# inv_cov_matrix = np.linalg.inv(cov_matrix)

# # Find the centroid of the most "popular" cluster (highest Pageviews)
# superstar_cluster = cluster_means['Pageviews'].idxmax()
# superstar_centroid = cluster_means.loc[superstar_cluster, feature_cols].values  # Explicitly select feature columns

# # Compute Mahalanobis distance for each player
# data_w_names['Obscurity_Score'] = data_w_names.apply(
#     lambda row: mahalanobis(row[feature_cols].values, superstar_centroid, inv_cov_matrix),
#     axis=1
# )

# %%
# from scipy.spatial.distance import euclidean
# from sklearn.preprocessing import MinMaxScaler

# # Select key performance metrics for defining "superstar" cluster
# performance_metrics = ['PTS_PerGame', 'AST_PerGame', 'TRB_PerGame', 'Pageviews', 'PTS', 'AST']

# # Normalize the data so no single stat dominates
# scaler = MinMaxScaler()
# normalized_means = cluster_means[performance_metrics].copy()
# normalized_means[performance_metrics] = scaler.fit_transform(normalized_means[performance_metrics])

# # Define superstar cluster as the one with the highest sum of normalized scores
# superstar_cluster = normalized_means.sum(axis=1).idxmax()

# # Get centroid of the superstar cluster
# superstar_centroid = cluster_means.loc[superstar_cluster, performance_metrics].values

# # Compute distance of each player from the superstar cluster
# data_w_names['Obscurity_Score'] = data_w_names.apply(
#     lambda row: euclidean(row[performance_metrics].values, superstar_centroid),
#     axis=1
# )

# # Lower 'Obscurity_Score' means more similar to superstars

# %%
# import numpy as np

# # Apply log transform to high-variance features (like Pageviews)
# log_features = ['Pageviews']
# # data_w_names[log_features] = np.log1p(data_w_names[log_features])
# cluster_means[log_features] = np.log1p(cluster_means[log_features] + 1)

# %%
# from sklearn.decomposition import PCA
# from scipy.spatial.distance import euclidean

# # Select performance-related features
# features = ['PTS_PerGame', 'AST_PerGame', 'TRB_PerGame', 'Pageviews', 'PTS', 'AST']

# # Apply PCA
# pca = PCA(n_components=1)  # Reduce to a single performance component
# pca_scores = pca.fit_transform(cluster_means[features])

# # Identify cluster with highest PCA score (most superstar-like)
# superstar_cluster = pca_scores.argmax()
# superstar_centroid = cluster_means.iloc[superstar_cluster][features].values

# # Compute Obscurity Score based on PCA-defined superstars
# data_w_names['Obscurity_Score'] = data_w_names.apply(
#     lambda row: euclidean(row[features].values, superstar_centroid),
#     axis=1
# )

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 100))
data_w_names['Obscurity_Score'] = scaler.fit_transform(data_w_names[['Obscurity_Score']])

# Higher score = More obscure player
data_w_names = data_w_names.sort_values(by='Obscurity_Score', ascending=False)

# %%
print(data_w_names[['Player_df2_x', 'Pageviews', 'PTS_PerGame', 'Obscurity_Score']].tail(25))
# Out:
#               Player_df2_x  Pageviews  PTS_PerGame  Obscurity_Score
# 382             Kyle Lowry   1.368880     0.843585        78.774368
# 17            Jaylen Brown   7.150165     1.650974        78.628711
# 392           Devin Booker   4.024531     2.568660        78.605697
# 334     Karl-Anthony Towns   4.962992     2.347540        78.039321
# 210          Kawhi Leonard   4.059578     1.834738        77.731542
# 21            Jrue Holiday   4.872790     1.168037        77.659502
# 150       Jimmy Butler III   3.893320     1.557152        76.262224
# 113          Klay Thompson   6.177358     1.725604        74.980101
# 428          DeMar DeRozan   2.819095     2.047497        74.649831
# 100          Anthony Davis   3.638627     2.529220        74.144487
# 378            Paul George   3.661930     1.953198        72.785444
# 275         Damian Lillard   2.942778     2.691244        71.853241
# 292        Anthony Edwards  17.529495     2.389914        71.167328
# 377            Joel Embiid   8.729996     3.134861        71.127413
# 29            Jayson Tatum  11.181754     2.409520        70.681435
# 208           James Harden   4.317409     2.513831        66.622124
# 217            Luka Dončić  14.676236     3.280116        66.241970
# 454             Chris Paul   4.991445     1.383796        65.113122
# 106           Kyrie Irving  11.874334     2.439544        64.583677
# 132      Russell Westbrook   5.370968     2.070970        63.821186
# 121           Nikola Jokić  12.778134     2.073763        63.790844
# 269  Giannis Antetokounmpo   9.253704     2.456080        63.751482
# 395           Kevin Durant  12.148700     3.049633        53.059399
# 151          Stephen Curry  20.790106     2.621946        45.283275
# 222           LeBron James  36.538089     3.013356         0.000000

# %%
df_combined = players.join(data_w_names["Obscurity_Score"], how='inner')  # 'inner', 'left', 'right', or 'outer'

# %%
def scale_obscurity(obscurity_score):
    if obscurity_score <= 70:
        return 0  # Set all values ≤ 70 to zero
    else:
        return ((obscurity_score - 70) / (100 - 70)) * 99 + 1  # Scale from 1 to 100

# %%
def scale_obscurity_exp(score):
    if score <= 70:
        return 0
    return (np.exp((score - 70) / 10) - 1) * (99 / (np.exp(2.5) - 1))  # More weight to higher values

# %%
import numpy as np

def scale_obscurity_sigmoid(score):
    if score <= 70:
        return 0  # Set values ≤ 70 to zero
    return 99 / (1 + np.exp(-0.2 * (score - 85)))  # Sigmoid curve with center at 85

# %%
df_combined['Obscurity_Score_Scaled'] = df_combined['Obscurity_Score'].apply(scale_obscurity_exp)

# %%
df_combined.sort_values(by='Obscurity_Score', ascending=False)[["Player", "Obscurity_Score_Scaled"]].tail(30)
# Out:
#                       Player  Obscurity_Score_Scaled
# 325            Jalen Brunson               18.767075
# 262               Kevin Love               17.756847
# 343  Shai Gilgeous-Alexander               13.973628
# 457        Victor Wembanyama               13.626933
# 22                Al Horford               12.544338
# 382               Kyle Lowry               12.436232
# 17              Jaylen Brown               12.128384
# 392             Devin Booker               12.080152
# 334       Karl-Anthony Towns               10.927491
# 210            Kawhi Leonard               10.327960
# 21              Jrue Holiday               10.190276
# 150             Jimmy Butler                7.706919
# 113            Klay Thompson                5.714193
# 428            DeMar DeRozan                5.240937
# 100            Anthony Davis                4.546398
# 378              Paul George                2.843670
# 275           Damian Lillard                1.802571
# 292          Anthony Edwards                1.096186
# 377              Joel Embiid                1.056553
# 29              Jayson Tatum                0.624313
# 208             James Harden                0.000000
# 217              Luka Dončić                0.000000
# 454               Chris Paul                0.000000
# 106             Kyrie Irving                0.000000
# 132        Russell Westbrook                0.000000
# 121             Nikola Jokić                0.000000
# 269    Giannis Antetokounmpo                0.000000
# 395             Kevin Durant                0.000000
# 151            Stephen Curry                0.000000
# 222             LeBron James                0.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))
sns.histplot(df_combined['Obscurity_Score'], bins=30, kde=True)
plt.xlabel("Obscurity Score")
plt.ylabel("Count")
plt.title("Distribution of Obscurity Scores")
plt.show()

# %%
df_combined.to_csv("../nba_locked.csv")

# %%
data.loc[data_w_names[data_w_names["Player_df2_x"] == "Bronny James"].index].T
# Out:
#                       223
# Pageviews       12.448660
# G               -0.973830
# GS              -0.830840
# All_Star        -0.545207
# MP              -0.834768
# FG              -0.727650
# FGA             -0.731524
# 2P              -0.675714
# 2PA             -0.671998
# 3P              -0.689570
# 3PA             -0.712983
# FT              -0.576403
# FTA             -0.593772
# ORB             -0.659011
# DRB             -0.727378
# TRB             -0.726697
# AST             -0.588563
# STL             -0.736550
# BLK             -0.616618
# TOV             -0.681212
# PF              -0.882104
# PTS             -0.712962
# FG%             -3.313893
# 2P%             -2.856044
# 3P%             -2.877774
# FT%              2.144058
# TS%             -3.514285
# eFG%            -3.901436
# MVP             -0.109744
# ROY             -0.173902
# DPOY            -0.090670
# All_NBA         -0.211872
# Champ           -0.344659
# IG               0.871688
# Team_Pageviews   2.924317
# MP_PerGame      -1.962241
# FG_PerGame      -1.491138
# FGA_PerGame     -1.387794
# 2P_PerGame      -1.284104
# 2PA_PerGame     -1.201446
# 3P_PerGame      -1.229950
# 3PA_PerGame     -1.172191
# FT_PerGame      -0.920442
# FTA_PerGame     -1.007619
# ORB_PerGame     -1.102363
# DRB_PerGame     -1.597921
# TRB_PerGame     -1.536255
# AST_PerGame     -0.986668
# STL_PerGame     -1.422599
# BLK_PerGame     -0.780625
# TOV_PerGame     -1.425789
# PF_PerGame      -2.015046
# PTS_PerGame     -1.429850
# cluster          7.000000
# PCA1            -0.459401
# PCA2            12.920404

# %%
data_w_names[data_w_names["Player_df2_x"] == "Bronny James"].T
# Out:
#                           223
# Pageviews            12.44866
# G                    -0.97383
# GS                   -0.83084
# All_Star            -0.545207
# MP                  -0.834768
# FG                   -0.72765
# FGA                 -0.731524
# 2P                  -0.675714
# 2PA                 -0.671998
# 3P                   -0.68957
# 3PA                 -0.712983
# FT                  -0.576403
# FTA                 -0.593772
# ORB                 -0.659011
# DRB                 -0.727378
# TRB                 -0.726697
# AST                 -0.588563
# STL                  -0.73655
# BLK                 -0.616618
# TOV                 -0.681212
# PF                  -0.882104
# PTS                 -0.712962
# FG%                 -3.313893
# 2P%                 -2.856044
# 3P%                 -2.877774
# FT%                  2.144058
# TS%                 -3.514285
# eFG%                -3.901436
# MVP                 -0.109744
# ROY                 -0.173902
# DPOY                 -0.09067
# All_NBA             -0.211872
# Champ               -0.344659
# IG                   0.871688
# Team_Pageviews       2.924317
# MP_PerGame          -1.962241
# FG_PerGame          -1.491138
# FGA_PerGame         -1.387794
# 2P_PerGame          -1.284104
# 2PA_PerGame         -1.201446
# 3P_PerGame           -1.22995
# 3PA_PerGame         -1.172191
# FT_PerGame          -0.920442
# FTA_PerGame         -1.007619
# ORB_PerGame         -1.102363
# DRB_PerGame         -1.597921
# TRB_PerGame         -1.536255
# AST_PerGame         -0.986668
# STL_PerGame         -1.422599
# BLK_PerGame         -0.780625
# TOV_PerGame         -1.425789
# PF_PerGame          -2.015046
# PTS_PerGame          -1.42985
# cluster                     7
# PCA1                -0.459401
# PCA2                12.920404
# Player_df2_x     Bronny James
# Obscurity_Score     86.660753
